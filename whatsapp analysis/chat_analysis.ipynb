# %%
import re
import pandas as pd

# %%
f=open('WhatsApp Chat with Fukrain.txt','r',encoding='utf-8')
data=f.read()

# %%
print(data)
# Out:
# 03/04/21, 11:46 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 03/04/21, 11:45 pm - Souvik created group "Roommates"
# 03/04/21, 11:45 pm - Souvik added you
# 03/04/21, 11:46 pm - You're now an admin
# 03/04/21, 11:47 pm - Atanu2 changed the subject from "Roommates" to "Machudain"
# 03/04/21, 11:47 pm - You changed the subject from "Machudain" to "Leodaian"
# 03/04/21, 11:47 pm - Souvik changed the group description
# 03/04/21, 11:48 pm - You changed the subject from "Leodaian" to "Sunny leone ki bhajan"
# 03/04/21, 11:48 pm - Souvik changed the subject from "Sunny leone ki bhajan" to "Chutiyappa overload"
# 03/04/21, 11:49 pm - You changed the subject from "Chutiyappa overload" to "Green bedsheet a chudai"
# 03/04/21, 11:50 pm - Souvik changed the subject from "Green bedsheet a chudai" to "Roommates"
# 03/04/21, 11:50 pm - You changed the subject from "Roommates" to "Mechanical eng."
# ...

# %%
pattern= '\d{1,2}/\d{1,2}/\{2,4},\s\d{1,2}:\d{2}\s(am|pm)\s-\s'

# %%
messages=re.split(pattern,data)
messages
# Out:
# ['03/04/21, 11:46 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n03/04/21, 11:45 pm - Souvik created group "Roommates"\n03/04/21, 11:45 pm - Souvik added you\n03/04/21, 11:46 pm - You\'re now an admin\n03/04/21, 11:47 pm - Atanu2 changed the subject from "Roommates" to "Machudain"\n03/04/21, 11:47 pm - You changed the subject from "Machudain" to "Leodaian"\n03/04/21, 11:47 pm - Souvik changed the group description\n03/04/21, 11:48 pm - You changed the subject from "Leodaian" to "Sunny leone ki bhajan"\n03/04/21, 11:48 pm - Souvik changed the subject from "Sunny leone ki bhajan" to "Chutiyappa overload"\n03/04/21, 11:49 pm - You changed the subject from "Chutiyappa overload" to "Green bedsheet a chudai"\n03/04/21, 11:50 pm - Souvik changed the subject from "Green bedsheet a chudai" to "Roommates"\n03/04/21, 11:50 pm - You changed the subject from "Roommates" to "Mechanical eng."\n03/04/2
# ...

# %%
dates=re.findall(pattern,data)
dates
# Out:
# []
